# %%
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
from sqlalchemy import create_engine, inspect, func
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/employees')
connection = engine.connect()

# %%
engine.execute('select * from salaries').fetchall()
# Out:
# [(10001, 60117),
#  (10002, 65828),
#  (10003, 40006),
#  (10004, 40054),
#  (10005, 78228),
#  (10006, 40000),
#  (10007, 56724),
#  (10008, 46671),
#  (10009, 60929),
#  (10010, 72488),
#  (10011, 42365),
#  (10012, 40000),
#  (10013, 40000),
#  (10014, 46168),
#  (10015, 40000),
#  (10016, 70889),
#  (10017, 71380),
#  (10018, 55881),
#  (10019, 44276),
#  (10020, 40000),
#  (10021, 55025),
#  (10022, 40000),
#  (10023, 47883),
#  (10024, 83733),
#  (10025, 40000),
#  (10026, 47585),
#  (10027, 40000),
#  (10028, 48859),
#  (10029, 63163),
#  (10030, 66956),
#  (10031, 40000),
#  (10032, 48426),
#  (10033, 51258),
#  (10034, 47561),
#  (10035, 41538),
#  (10036, 42819),
#  (10037, 40000),
#  (10038, 40000),
#  (10039, 40000),
#  (10040, 52153),
#  (10041, 56893),
#  (10042, 81662),
#  (10043, 49324),
#  (10044, 40919),
#  (10045, 41971),
#  (10046, 40000),
#  (10047, 54982),
#  (10048, 40000),
#  (10049, 40000),
#  (10050, 74366),
#  (10051, 48817),
#  (10052, 57212),
# ...

# %%
Base = automap_base()
Base.prepare(engine,reflect=True)
Salaries = Base.classes.salaries

# %%
session = Session(engine)

# %%
sel = [Salaries.emp_no,
      Salaries.salary]

# %%
common_salary = session.query(*sel).\
    group_by(Salaries.emp_no,Salaries.salary).limit(200)
common_salary

# %%
common_df = pd.DataFrame(common_salary, columns=['emp_no','salary'])
common_df.set_index('emp_no',inplace=True)
common_df.plot.bar()
plt.tight_layout()

# %%
plt.show()
